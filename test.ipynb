# %%
import pandas as pd
import pyodbc

# %%
conn_str = 'DRIVER={ODBC Driver 17 for SQL Server};\
            SERVER=MSI\DUCNAM;\
            DATABASE=AdventureWorksLT2019;\
            UID=dn;\
            PWD=123456'


conn = pyodbc.connect(conn_str)
query = "SELECT * FROM SalesLT.Product"
df = pd.read_sql(query, conn)
# Out:
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_17988\429798478.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df
# Out:
#      ProductID                       Name ProductNumber  Color  StandardCost  \
# 0          680  HL Road Frame - Black, 58    FR-R92B-58  Black     1059.3100
# 1          706    HL Road Frame - Red, 58    FR-R92R-58    Red     1059.3100
# 2          707      Sport-100 Helmet, Red     HL-U509-R    Red       13.0863
# 3          708    Sport-100 Helmet, Black       HL-U509  Black       13.0863
# 4          709     Mountain Bike Socks, M     SO-B909-M  White        3.3963
# ..         ...                        ...           ...    ...           ...
# 290        995          ML Bottom Bracket       BB-8107   None       44.9506
# 291        996          HL Bottom Bracket       BB-9108   None       53.9416
# 292        997         Road-750 Black, 44    BK-R19B-44  Black      343.6496
# 293        998         Road-750 Black, 48    BK-R19B-48  Black      343.6496
# 294        999         Road-750 Black, 52    BK-R19B-52  Black      343.6496
#
# ...

# %%
new = df['Name'].groupby().value_counts()["Name"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\HKI 2023-2024\Database\Pyodbc_test\test.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/HKI%202023-2024/Database/Pyodbc_test/test.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> new = df['Name'].groupby().value_counts()["Name"]
#
# File c:\Users\FPT SHOP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:2073, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    2070     squeeze = False
#    2072 if level is None and by is None:
# -> 2073     raise TypeError("You have to supply one of 'by' and 'level'")
#    2074 axis = self._get_axis_number(axis)
#    2076 return SeriesGroupBy(
#    2077     obj=self,
#    2078     keys=by,
#    (...)
#    2086     dropna=dropna,
#    2087 )
#
# TypeError: You have to supply one of 'by' and 'level'
